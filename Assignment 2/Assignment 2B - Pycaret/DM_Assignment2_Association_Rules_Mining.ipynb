# %%
# !pip install pycaret==3.0.0.rc1

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
bank_data = pd.read_csv("/content/gdrive/MyDrive/Datasets/bank.csv")

# %%
bank_data = bank_data.head(1000)

# %%
bank_data.shape
# Out:
# (1000, 9)

# %%
from pycaret.arules import *

# %%
bank_data = pd.melt(bank_data.reset_index(), id_vars=['index'], value_name='item').drop('variable', axis=1).dropna()
bank_data.columns = ['transaction_id', 'item_id']

bank_data.head()
# Out:
#    transaction_id        item_id
# 0               0  409000611074'
# 1               1  409000611074'
# 2               2  409000611074'
# 3               3  409000611074'
# 4               4  409000611074'

# %%
arules_setup = setup(bank_data,transaction_id='transaction_id',item_id='item_id')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b521f" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_b521f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_b521f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b521f_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b521f_row0_col1" class="data row0 col1" >2866</td>
#     </tr>
#     <tr>
#       <td id="T_b521f_row1_col0" class="data row1 col0" ># Transactions</td>
#       <td id="T_b521f_row1_col1" class="data row1 col1" >1000</td>
#     </tr>
#     <tr>
#       <td id="T_b521f_row2_col0" class="data row2 col0" ># Items</td>
#       <td id="T_b521f_row2_col1" class="data row2 col1" >2432</td>
#     </tr>
#     <tr>
#       <td id="T_b521f_row3_col0" class="data row3 col0" >Ignore Items</td>
#       <td id="T_b521f_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#   </tbody>
# ...

# %%
association_Rule_model =create_model(threshold=0.05, metric='support')
# Out:
# WARNING:logs:/usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
association_Rule_model
# Out:
# WARNING:logs:/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                                           antecedents  \
# 0                                                 (.)
# 1                                     (409000611074')
# 2                                     (409000611074')
# 3                                                 (.)
# 4         (409000611074', FDRL/INTERNAL FUND TRANSFE)
# 5                     (., FDRL/INTERNAL FUND TRANSFE)
# 6                                  (., 409000611074')
# 7                                                 (.)
# 8                        (FDRL/INTERNAL FUND TRANSFE)
# 9                                     (409000611074')
# ...
