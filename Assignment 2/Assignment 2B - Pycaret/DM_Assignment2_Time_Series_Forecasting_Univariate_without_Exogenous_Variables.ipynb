# %% [markdown]
# **Install Pycaret**

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 85.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 83.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 81.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
electric_prod_data = pd.read_csv("/content/gdrive/MyDrive/Datasets/Electric_Production.csv")

# %%
electric_prod_data.shape
# Out:
# (397, 2)

# %% [markdown]
# **Import Library**

# %%
from pycaret.time_series import *

# %% [markdown]
# **Setup**

# %%
time_series_setup = setup(electric_prod_data.IPG2211A2N,session_id = 123)
# Out:
# <style type="text/css">
# #T_011b2_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_011b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_011b2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_011b2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_011b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_011b2_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_011b2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_011b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_011b2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_011b2_row1_col1" class="data row1 col1" >IPG2211A2N</td>
#     </tr>
#     <tr>
#       <th id="T_011b2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
models()
# Out:
#                                                               Name  \
# ID
# naive                                             Naive Forecaster
# grand_means                                 Grand Means Forecaster
# snaive                                   Seasonal Naive Forecaster
# polytrend                              Polynomial Trend Forecaster
# arima                                                        ARIMA
# auto_arima                                              Auto ARIMA
# exp_smooth                                   Exponential Smoothing
# ets                                                            ETS
# theta                                             Theta Forecaster
# stlf                                                          STLF
# croston                                                    Croston
# bats                                                          BATS
# tbats                                                        TBATS
# ...

# %% [markdown]
# **Create Model**

# %%
ets = create_model("ets")
print(ets)
# Out:
# <style type="text/css">
# #T_da944_row3_col0, #T_da944_row3_col1, #T_da944_row3_col2, #T_da944_row3_col3, #T_da944_row3_col4, #T_da944_row3_col5, #T_da944_row3_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_da944" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da944_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_da944_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_da944_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_da944_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_da944_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_da944_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_da944_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
snaive = create_model("snaive")
print(snaive)
# Out:
# <style type="text/css">
# #T_f9c42_row3_col0, #T_f9c42_row3_col1, #T_f9c42_row3_col2, #T_f9c42_row3_col3, #T_f9c42_row3_col4, #T_f9c42_row3_col5, #T_f9c42_row3_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f9c42" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9c42_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_f9c42_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_f9c42_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_f9c42_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_f9c42_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_f9c42_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_f9c42_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
naive = create_model("naive")
print(naive)
# Out:
# <style type="text/css">
# #T_66e91_row3_col0, #T_66e91_row3_col1, #T_66e91_row3_col2, #T_66e91_row3_col3, #T_66e91_row3_col4, #T_66e91_row3_col5, #T_66e91_row3_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_66e91" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66e91_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_66e91_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_66e91_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_66e91_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_66e91_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_66e91_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_66e91_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
arima = create_model("arima")
print(arima)
# Out:
# <style type="text/css">
# #T_18f43_row3_col0, #T_18f43_row3_col1, #T_18f43_row3_col2, #T_18f43_row3_col3, #T_18f43_row3_col4, #T_18f43_row3_col5, #T_18f43_row3_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_18f43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18f43_level0_col0" class="col_heading level0 col0" >cutoff</th>
#       <th id="T_18f43_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_18f43_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_18f43_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_18f43_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_18f43_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_18f43_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# **Plot graph**

# %%
plot_model(arima, plot = 'forecast')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plot_model(arima, plot = 'forecast', data_kwargs = {'fh' : 36})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Predictions**

# %%
predictions = predict_model(arima)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5939b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5939b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_5939b_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_5939b_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_5939b_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_5939b_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_5939b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_5939b_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5939b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5939b_row0_col0" class="data row0 col0" >ARIMA</td>
#       <td id="T_5939b_row0_col1" class="data row0 col1" >4.5805</td>
# ...
