# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Install library**

# %%
# !pip install pycaret
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 69.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 69.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.2 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
movies = pd.read_csv("/content/gdrive/MyDrive/Datasets/movie-genre.csv")

# %%
movies
# Out:
#           id                                         movie_name  \
# 0      44978                                           Super Me
# 1      50185                                     Entity Project
# 2      34131  Behavioral Family Therapy for Serious Psychiat...
# 3      78522                                      Blood Glacier
# 4       2206                                      Apat na anino
# ...      ...                                                ...
# 53995  80325          Untitled Monkeyshine/Ugly Brother Project
# 53996  84712                                  The Great Swindle
# 53997  69801                              When Men Get Pregnant
# 53998   7678                             Suttu Pidikka Utharavu
# 53999  33970                                    Margo the Mouse
#
#                                                 synopsis     genre
# 0      A young scriptwriter starts bringing valuable ...   fantasy
# ...

# %%
movies_dataset = movies.head(1000)

# %%
movies_dataset.shape
# Out:
# (1000, 4)

# %% [markdown]
# **Import Library**

# %%
from pycaret.classification import *

# %% [markdown]
# **Setup**

# %%
multi_class = setup(data=movies_dataset,target="genre",session_id=123)
# Out:
# <style type="text/css">
# #T_98307_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_98307" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98307_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_98307_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98307_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98307_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_98307_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_98307_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98307_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_98307_row1_col1" class="data row1 col1" >genre</td>
#     </tr>
#     <tr>
#       <th id="T_98307_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# **Compare Model**

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_b64b1 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# **Plot Model**

# %%
plot_model(best_model, plot = 'confusion_matrix')

# %%
plot_model(best_model, plot = 'auc')

# %%
plot_model(best_model, plot = 'feature')

# %% [markdown]
# **Evaluate Model**

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# **Predictions**

# %%
predictions = predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_edf14" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_edf14_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_edf14_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_edf14_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_edf14_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_edf14_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_edf14_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_edf14_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_edf14_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_edf14_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
final_model = finalize_model(best_model)

# %%
final_model
# Out:
# Pipeline(memory=Memory(location=None),
#          steps=[('label_encoding',
#                  TransformerWrapperWithInverse(exclude=None, include=None,
#                                                transformer=LabelEncoder())),
#                 ('numerical_imputer',
#                  TransformerWrapper(exclude=None, include=['id'],
#                                     transformer=SimpleImputer(add_indicator=False,
#                                                               copy=True,
#                                                               fill_value=None,
#                                                               keep_empty_features=False,
#                                                               missing_values=nan,
#                                                               strategy='mean',
#                                                               v...
#                                grow_policy=None, importance_type=None,
# ...

# %%
create_app(best_model)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# To create a public link, set `share=True` in `launch()`.
